# %% [markdown]
# <a href="https://colab.research.google.com/github/chhabradeevyansh001/Data-Science/blob/main/Pythonbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello this is Data science course")
# Out:
# hello this is Data science course

# %%
name= "DEEVYANSH CHHABRA"
age = 25
is_student = True

# %%
#typecasting

#str to int
x = int("10")
print(x)

#int to str
y = str(25)
print(y)

#float to int
z = int(3.19)
print(z)

#string to list
l = list("abc")
print(l)
# Out:
# 10
# 25
# 3
# ['a', 'b', 'c']

# %%
text="DEEVYANSH"
for i in range(len(text)):
    print(text[i])
print(text[0:2])# 1 kam print hota hai(2-1=1[0 to 1])

    #strings are immutable can not be changed after creation
# Out:
# D
# E
# E
# V
# Y
# A
# N
# S
# H
# DE
